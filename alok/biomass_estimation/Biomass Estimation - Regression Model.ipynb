# %% [markdown]
# <h1> Biomass Regression Model </h1>

# %%
import array
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
import json
import math
import statsmodels.api as sm
from matplotlib import pyplot as plt
pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)

# %matplotlib inline

# %% [markdown]
# <h1> Create dataframe with relevant features </h1>

# %%
data_dir_base = '/root/data/blender_v3/'
COMPLETE_SAMPLE_SIZE = 4007
df = pd.DataFrame()
for idx in range(COMPLETE_SAMPLE_SIZE):
    # get annotation data
    annotation_file_name = 'annot_{}.json'.format(idx)
    annotation_file_path = '{}/{}/{}'.format(data_dir_base, 'annotations', annotation_file_name)
    annotation_data = json.load(open(annotation_file_path, 'rb'))
    df = df.append(annotation_data, ignore_index=True)

# add columns to DataFrame
df['log_volume'] = np.log(df.volume)
df['log_length'] = np.log(df.length)
df['log_width'] = np.log(df.height)
df['log_breadth'] = np.log(df.width)

# %% [markdown]
# <h1> Simple Allometric Models </h1>

# %% [markdown]
# We first consider the model $ W = al^b $, where $W$ and $l$ represent biomass and weight, respectively. First, rewrite the model as $\log{W} = a + b\log{l}$. We will fit the points to this model.

# %%
features = ['log_length']
target = 'log_volume'

model = sm.OLS(df[target], df.filter(features)).fit()
print(model.summary())

A = np.vstack([df.filter(features).values.T, np.ones(df.shape[0])]).T
res = np.linalg.lstsq(A, df[target].values)
b, a = res[0]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_volume   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 1.927e+06
# Date:                Thu, 14 Jun 2018   Prob (F-statistic):               0.00
# Time:                        20:10:26   Log-Likelihood:                -1558.2
# No. Observations:                4007   AIC:                             3118.
# Df Residuals:                    4006   BIC:                             3125.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# log_length     1.7590      0.001   1388.162      0.000       1.757       1.762
# ==============================================================================
# Omnibus:                     1268.441   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              264.572
# Skew:                          -0.347   Prob(JB):                     3.54e-58
# Kurtosis:                       1.950   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
df
# Out:
#       focal_length     height  interocular_distance      length  \
# 0              1.0  20.760459                  0.65  103.802296
# 1              1.0  21.529521                  0.65  107.647604
# 2              1.0  22.001732                  0.65  110.008658
# 3              1.0  18.319376                  0.65   91.596881
# 4              1.0  18.734798                  0.65   93.673988
# 5              1.0  16.761576                  0.65   83.807878
# 6              1.0  20.545638                  0.65  102.728189
# 7              1.0  21.861212                  0.65  109.306060
# 8              1.0  23.221622                  0.65  116.108112
# 9              1.0  11.978642                  0.65   59.893212
# 10             1.0  22.739985                  0.65  113.699926
# 11             1.0  12.852590                  0.65   64.262951
# 12             1.0  12.988791                  0.65   64.943954
# 13             1.0  19.946522                  0.65   99.732609
# 14             1.0  16.937225                  0.65   84.686123
# 15             1.0  21.109892                  0.65  105.549461
# 16             1.0  16.765707                  0.65   83.828534
# 17             1.0  16.339764                  0.65   81.698822
# 18             1.0  24.113331                  0.65  120.566653
# 19             1.0  19.468229                  0.65   97.341144
# 20             1.0  10.877890                  0.65   54.389448
# 21             1.0  10.560039                  0.65   52.800196
# 22             1.0  17.086066                  0.65   85.430332
# 3991           1.0  13.066811                  0.65   65.334057
# 3992           1.0  12.015541                  0.65   60.077704
# 3993           1.0  11.601585                  0.65   58.007927
# 3994           1.0  15.762796                  0.65   78.813982
# 3995           1.0  25.062683                  0.65  125.313416
# 3996           1.0  13.735310                  0.65   68.676550
# 3997           1.0  23.998499                  0.65  119.992495
# 3998           1.0  20.593828                  0.65  102.969140
# 3999           1.0  11.355004                  0.65   56.775018
# 4000           1.0  11.689791                  0.65   58.448956
# 4001           1.0  18.076954                  0.65   90.384772
# 4002           1.0  19.933366                  0.65   99.666828
# 4003           1.0  24.014493                  0.65  120.072467
# 4004           1.0  14.521962                  0.65   72.609810
# 4005           1.0  23.227020                  0.65  116.135100
# 4006           1.0  23.618333                  0.65  118.091667
#
#       sensor_height  sensor_width        unit unit_system       volume  \
# 0               3.2           1.8  centimeter      METRIC  4410.102565
# 1               3.2           1.8  centimeter      METRIC  4918.065291
# 2               3.2           1.8  centimeter      METRIC  5248.575445
# 3               3.2           1.8  centimeter      METRIC  3031.227486
# 4               3.2           1.8  centimeter      METRIC  3241.954948
# 5               3.2           1.8  centimeter      METRIC  2322.505339
# 6               3.2           1.8  centimeter      METRIC  4274.685574
# 7               3.2           1.8  centimeter      METRIC  5148.768655
# 8               3.2           1.8  centimeter      METRIC  6170.065679
# 9               3.2           1.8  centimeter      METRIC   848.807730
# 10              3.2           1.8  centimeter      METRIC  5794.377109
# 11              3.2           1.8  centimeter      METRIC  1048.165130
# 12              3.2           1.8  centimeter      METRIC  1081.754256
# 13              3.2           1.8  centimeter      METRIC  3911.908801
# 14              3.2           1.8  centimeter      METRIC  2396.136391
# 15              3.2           1.8  centimeter      METRIC  4636.330812
# 16              3.2           1.8  centimeter      METRIC  2324.214086
# 17              3.2           1.8  centimeter      METRIC  2151.672698
# 18              3.2           1.8  centimeter      METRIC  6907.831024
# 19              3.2           1.8  centimeter      METRIC  3637.426301
# 20              3.2           1.8  centimeter      METRIC   635.955601
# 21              3.2           1.8  centimeter      METRIC   581.902053
# 22              3.2           1.8  centimeter      METRIC  2459.885946
# 23              3.2           1.8  centimeter      METRIC   413.358528
# 24              3.2           1.8  centimeter      METRIC  3100.393911
# 25              3.2           1.8  centimeter      METRIC  6680.467904
# 26              3.2           1.8  centimeter      METRIC  4985.242590
# 27              3.2           1.8  centimeter      METRIC  2956.193341
# 28              3.2           1.8  centimeter      METRIC  3542.046944
# 29              3.2           1.8  centimeter      METRIC  6615.410147
# 30              3.2           1.8  centimeter      METRIC  3628.503246
# 31              3.2           1.8  centimeter      METRIC   539.420092
# 32              3.2           1.8  centimeter      METRIC  1463.347977
# 33              3.2           1.8  centimeter      METRIC  1157.867960
# 34              3.2           1.8  centimeter      METRIC  6758.066479
# 35              3.2           1.8  centimeter      METRIC  6133.094585
# 36              3.2           1.8  centimeter      METRIC   705.097886
# 37              3.2           1.8  centimeter      METRIC   699.079366
# 38              3.2           1.8  centimeter      METRIC   946.334464
# 39              3.2           1.8  centimeter      METRIC  1470.537967
# 40              3.2           1.8  centimeter      METRIC  2914.954077
# 41              3.2           1.8  centimeter      METRIC  6327.485844
# 42              3.2           1.8  centimeter      METRIC  2968.696965
# 43              3.2           1.8  centimeter      METRIC  5422.710184
# 44              3.2           1.8  centimeter      METRIC   466.777763
# 45              3.2           1.8  centimeter      METRIC   788.309192
# 46              3.2           1.8  centimeter      METRIC  1234.161194
# 47              3.2           1.8  centimeter      METRIC  3621.295852
# 48              3.2           1.8  centimeter      METRIC  2554.913397
# 49              3.2           1.8  centimeter      METRIC  6742.797199
# 50              3.2           1.8  centimeter      METRIC  2304.219826
# 51              3.2           1.8  centimeter      METRIC  5957.540778
# 52              3.2           1.8  centimeter      METRIC  2062.906596
# 53              3.2           1.8  centimeter      METRIC  2173.886635
# 54              3.2           1.8  centimeter      METRIC  6210.902492
# 55              3.2           1.8  centimeter      METRIC  6239.362042
# 56              3.2           1.8  centimeter      METRIC  8234.064470
# 57              3.2           1.8  centimeter      METRIC  4321.633532
# 58              3.2           1.8  centimeter      METRIC  2461.481443
# 59              3.2           1.8  centimeter      METRIC   451.246550
# 60              3.2           1.8  centimeter      METRIC  5287.712334
# 61              3.2           1.8  centimeter      METRIC  7068.276244
# 62              3.2           1.8  centimeter      METRIC  7258.640137
# 63              3.2           1.8  centimeter      METRIC  3435.063277
# 64              3.2           1.8  centimeter      METRIC  7901.697035
# 65              3.2           1.8  centimeter      METRIC   903.196733
# 66              3.2           1.8  centimeter      METRIC  8037.941338
# 67              3.2           1.8  centimeter      METRIC  2120.109414
# 68              3.2           1.8  centimeter      METRIC   723.111602
# 69              3.2           1.8  centimeter      METRIC  6964.720561
# 70              3.2           1.8  centimeter      METRIC  8084.034327
# 71              3.2           1.8  centimeter      METRIC  1327.077567
# 72              3.2           1.8  centimeter      METRIC  3753.976274
# 73              3.2           1.8  centimeter      METRIC  1411.226813
# 74              3.2           1.8  centimeter      METRIC  4786.088204
# 75              3.2           1.8  centimeter      METRIC  8296.692265
# 76              3.2           1.8  centimeter      METRIC   525.130534
# 77              3.2           1.8  centimeter      METRIC  8083.312396
# 78              3.2           1.8  centimeter      METRIC   470.017156
# 79              3.2           1.8  centimeter      METRIC  1063.549089
# 80              3.2           1.8  centimeter      METRIC  2137.045479
# 81              3.2           1.8  centimeter      METRIC  2377.758371
# 82              3.2           1.8  centimeter      METRIC  3825.508050
# 83              3.2           1.8  centimeter      METRIC  2428.747047
# 84              3.2           1.8  centimeter      METRIC  6147.203243
# 85              3.2           1.8  centimeter      METRIC  1164.941005
# 86              3.2           1.8  centimeter      METRIC  1539.502570
# 87              3.2           1.8  centimeter      METRIC   739.919278
# 88              3.2           1.8  centimeter      METRIC  2167.426206
# 89              3.2           1.8  centimeter      METRIC  4151.967234
# 90              3.2           1.8  centimeter      METRIC  4255.587768
# 91              3.2           1.8  centimeter      METRIC  2312.017783
# 92              3.2           1.8  centimeter      METRIC  1886.742795
# 93              3.2           1.8  centimeter      METRIC  1500.318117
# 94              3.2           1.8  centimeter      METRIC  1538.793037
# 95              3.2           1.8  centimeter      METRIC  1126.783898
# 96              3.2           1.8  centimeter      METRIC   557.448829
# 97              3.2           1.8  centimeter      METRIC  1444.205587
# 98              3.2           1.8  centimeter      METRIC  1590.858531
# 99              3.2           1.8  centimeter      METRIC  3864.999944
# 100             3.2           1.8  centimeter      METRIC  1441.968148
# 101             3.2           1.8  centimeter      METRIC  4780.013775
# 102             3.2           1.8  centimeter      METRIC  1087.353517
# 103             3.2           1.8  centimeter      METRIC  5622.101081
# 104             3.2           1.8  centimeter      METRIC  3180.212401
# 105             3.2           1.8  centimeter      METRIC  3970.668732
# 106             3.2           1.8  centimeter      METRIC  4428.791721
# 107             3.2           1.8  centimeter      METRIC  1747.649748
# 108             3.2           1.8  centimeter      METRIC   800.908661
# 109             3.2           1.8  centimeter      METRIC  3547.875563
# 110             3.2           1.8  centimeter      METRIC  4418.043334
# 111             3.2           1.8  centimeter      METRIC  5321.295976
# 112             3.2           1.8  centimeter      METRIC   639.149337
# 113             3.2           1.8  centimeter      METRIC   471.589735
# 114             3.2           1.8  centimeter      METRIC  2247.775178
# 115             3.2           1.8  centimeter      METRIC  1403.012338
# 116             3.2           1.8  centimeter      METRIC   629.674105
# 117             3.2           1.8  centimeter      METRIC   891.969601
# 118             3.2           1.8  centimeter      METRIC   476.755789
# 119             3.2           1.8  centimeter      METRIC  7242.098178
# 120             3.2           1.8  centimeter      METRIC  5738.590974
# 121             3.2           1.8  centimeter      METRIC   607.698647
# 122             3.2           1.8  centimeter      METRIC   567.356493
# 123             3.2           1.8  centimeter      METRIC  7980.624079
# 124             3.2           1.8  centimeter      METRIC  5926.497248
# 125             3.2           1.8  centimeter      METRIC  1554.480265
# 126             3.2           1.8  centimeter      METRIC   737.673673
# 127             3.2           1.8  centimeter      METRIC  5633.967651
# 128             3.2           1.8  centimeter      METRIC  6546.985442
# 129             3.2           1.8  centimeter      METRIC  5276.693103
# 130             3.2           1.8  centimeter      METRIC  8125.639325
# 131             3.2           1.8  centimeter      METRIC  8626.955418
# 132             3.2           1.8  centimeter      METRIC  3565.193812
# 133             3.2           1.8  centimeter      METRIC  7970.666288
# 134             3.2           1.8  centimeter      METRIC  1157.155685
# 135             3.2           1.8  centimeter      METRIC  3769.225527
# 136             3.2           1.8  centimeter      METRIC   986.201926
# 137             3.2           1.8  centimeter      METRIC   859.033921
# 138             3.2           1.8  centimeter      METRIC  6523.052984
# 139             3.2           1.8  centimeter      METRIC  7296.150534
# 140             3.2           1.8  centimeter      METRIC  2917.341601
# 141             3.2           1.8  centimeter      METRIC  1897.447432
# 142             3.2           1.8  centimeter      METRIC  1324.661314
# 143             3.2           1.8  centimeter      METRIC   699.168892
# 144             3.2           1.8  centimeter      METRIC  2593.416807
# 145             3.2           1.8  centimeter      METRIC   825.955726
# 146             3.2           1.8  centimeter      METRIC  6036.408694
# 147             3.2           1.8  centimeter      METRIC  8170.969375
# 148             3.2           1.8  centimeter      METRIC  2129.692411
# 149             3.2           1.8  centimeter      METRIC  1368.153872
# 150             3.2           1.8  centimeter      METRIC  1643.046333
# 151             3.2           1.8  centimeter      METRIC   467.175087
# 152             3.2           1.8  centimeter      METRIC  2447.430958
# 153             3.2           1.8  centimeter      METRIC  3930.076536
# 154             3.2           1.8  centimeter      METRIC  2442.483773
# 155             3.2           1.8  centimeter      METRIC  1439.249103
# 156             3.2           1.8  centimeter      METRIC  1748.261411
# 157             3.2           1.8  centimeter      METRIC   606.851247
# 158             3.2           1.8  centimeter      METRIC  1466.754025
# 159             3.2           1.8  centimeter      METRIC   483.535133
# 160             3.2           1.8  centimeter      METRIC  6106.846606
# 161             3.2           1.8  centimeter      METRIC  2640.181421
# 162             3.2           1.8  centimeter      METRIC  2537.830943
# 163             3.2           1.8  centimeter      METRIC  1591.594648
# 164             3.2           1.8  centimeter      METRIC  4103.857701
# 165             3.2           1.8  centimeter      METRIC   677.709669
# 166             3.2           1.8  centimeter      METRIC  1730.967003
# 167             3.2           1.8  centimeter      METRIC  4820.998407
# 168             3.2           1.8  centimeter      METRIC   743.333909
# 169             3.2           1.8  centimeter      METRIC   459.164521
# 170             3.2           1.8  centimeter      METRIC  1640.939190
# 171             3.2           1.8  centimeter      METRIC  5828.748964
# 172             3.2           1.8  centimeter      METRIC  2733.046177
# 173             3.2           1.8  centimeter      METRIC  1582.537126
# 174             3.2           1.8  centimeter      METRIC   832.414783
# 175             3.2           1.8  centimeter      METRIC  4187.708565
# 176             3.2           1.8  centimeter      METRIC   626.602976
# 177             3.2           1.8  centimeter      METRIC  2447.824349
# 178             3.2           1.8  centimeter      METRIC  1673.831418
# 179             3.2           1.8  centimeter      METRIC   823.983110
# 180             3.2           1.8  centimeter      METRIC   435.513099
# 181             3.2           1.8  centimeter      METRIC  3389.772328
# 182             3.2           1.8  centimeter      METRIC  7194.503629
# 183             3.2           1.8  centimeter      METRIC  1650.606229
# 184             3.2           1.8  centimeter      METRIC  2301.717384
# 185             3.2           1.8  centimeter      METRIC  2037.523838
# 186             3.2           1.8  centimeter      METRIC   734.893653
# 187             3.2           1.8  centimeter      METRIC  2307.328327
# 188             3.2           1.8  centimeter      METRIC  3344.893843
# 189             3.2           1.8  centimeter      METRIC   629.446654
# 190             3.2           1.8  centimeter      METRIC  1636.622502
# 191             3.2           1.8  centimeter      METRIC   613.071469
# 192             3.2           1.8  centimeter      METRIC   535.898888
# ...
# 3765  10.897849    7.006737    4.180325   2.570887     2.388565
# 3766  20.657750    8.923303    4.819850   3.210412     3.028091
# 3767  13.774983    7.708715    4.414614   2.805176     2.622854
# 3768  18.696733    8.624298    4.720108   3.110670     2.928349
# 3769  10.679347    6.946059    4.160071   2.550633     2.368312
# 3770  12.456722    7.407292    4.314020   2.704582     2.522260
# 3771  17.563572    8.436902    4.657586   3.048149     2.865827
# 3772  11.089409    7.058942    4.197750   2.588312     2.405990
# 3773  15.827744    8.125004    4.553524   2.944086     2.761764
# 3774  19.843114    8.802687    4.779617   3.170179     2.987857
# 3775  19.903237    8.811762    4.782642   3.173204     2.990882
# 3776   8.560327    6.283610    3.938898   2.329460     2.147138
# 3777  17.727503    8.464745    4.666877   3.057439     2.875117
# 3778  17.352956    8.400741    4.645522   3.036084     2.853763
# 3779  20.035984    8.831684    4.789289   3.179851     2.997530
# 3987  14.449576    7.851980    4.462425   2.852987     2.670665
# 3988  15.211990    8.006065    4.513843   2.904405     2.722084
# 3989  20.497579    8.899966    4.812066   3.202628     3.020307
# 3990  18.319394    8.563202    4.699720   3.090282     2.907960
# 3991  10.889009    7.004279    4.179513   2.570076     2.387754
# 3992  10.012951    6.753036    4.095639   2.486201     2.303879
# 3993   9.667988    6.648014    4.060580   2.451142     2.268820
# 3994  13.135664    7.566295    4.367090   2.757653     2.575331
# 3995  20.885569    8.956188    4.830818   3.221380     3.039058
# 3996  11.446092    7.153775    4.229408   2.619970     2.437648
# 3997  19.998749    8.826119    4.787429   3.177991     2.995670
# 3998  17.161523    8.367488    4.634429   3.024991     2.842670
# 3999   9.462503    6.583676    4.039096   2.429658     2.247337
# 4000   9.741493    6.670713    4.068154   2.458716     2.276394
# 4001  15.064129    7.976810    4.504076   2.894638     2.712316
# 4002  16.611138    8.269806    4.601833   2.992395     2.810073
# 4003  20.012078    8.828110    4.788095   3.178658     2.996336
# 4004  12.101635    7.320644    4.285100   2.675662     2.493341
# 4005  19.355850    8.728159    4.754754   3.145316     2.962995
# 4006  19.681945    8.778236    4.771461   3.162023     2.979702
#
# [4007 rows x 14 columns]

# %% [markdown]
# Now consider the following model, which is the first model but generalized to incorporate other dimensions as well (width and breadth):
#
# $$W=al^b w^c b^d$$
#
# Here, $W$, $l$, $w$ and $b$ represent biomass, length, width, and breadth, respectively. Taking logarithms, this gives
#
# $$ \log{W} = a + b\log{l} + c\log{w} + d\log{b} $$

# %%
features = ['log_length', 'log_width', 'log_breadth']
target = 'log_volume'

model = sm.OLS(df[target], df.filter(features)).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_volume   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.663e+11
# Date:                Thu, 24 May 2018   Prob (F-statistic):               0.00
# Time:                        23:17:38   Log-Likelihood:                 30051.
# No. Observations:                4007   AIC:                        -6.010e+04
# Df Residuals:                    4005   BIC:                        -6.009e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# log_length     -0.2384   1.18e-05  -2.02e+04      0.000      -0.238      -0.238
# log_width       1.5180   8.41e-06    1.8e+05      0.000       1.518       1.518
# log_breadth     1.7169   1.07e-05    1.6e+05      0.000       1.717       1.717
# ==============================================================================
# Omnibus:                      320.695   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              395.973
# Skew:                           0.762   Prob(JB):                     1.04e-86
# Kurtosis:                       2.780   Cond. No.                     6.31e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.52e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-739efdc9d494> in <module>()
#       7 A = np.vstack([df.filter(features).values.T, np.ones(df.shape[0])]).T
#       8 res = np.linalg.lstsq(A, df[target].values)
# ----> 9 b, a = res[0]
#
# ValueError: too many values to unpack (expected 2)

# %%
model.params
# Out:
# log_length    -0.238440
# log_width      1.517973
# log_breadth    1.716944
# dtype: float64

# %%
features = ['log_length', 'log_width', 'log_breadth']
A = np.vstack([df[features].values.T, np.ones(df.shape[0])]).T
res = np.linalg.lstsq(A, df[target].values)

# %%
np.dot(res[0].T, A.T)
# Out:
# array([[ 8.39167452,  8.50067115,  8.56568289, ...,  7.32076955,
#          8.72807741,  8.77813947]])

# %%
np.dot(res[0].T, A.T)
# Out:
# array([[ 8.39167452,  8.50067115,  8.56568289, ...,  7.32076955,
#          8.72807741,  8.77813947]])

# %%
res[0].T.shape, A.T.shape
# Out:
# ((1, 4), (4, 4007))

# %%
res
# Out:
# (array([ -7.19356492e+07,   9.15796487e+07,  -1.96439965e+07,
#           1.12194436e+08]),
#  array([], dtype=float64),
#  3,
#  array([  3.60299720e+02,   8.58442905e+00,   1.08146712e-13,
#           9.54306990e-15]))

# %% [markdown]
# <h1> k-fold Cross Validation </h1>

# %%
results_df = pd.DataFrame()

# specify the allometric models that we want to compare

models = {}
models['model_1'] = {
    'features': ['log_length'],
    'target': 'log_volume'
}
models['model_2'] = {
    'features': ['log_length', 'log_width', 'log_breadth'],
    'target': 'log_volume'
}

# specify the cross validation size
k = 10

# perform k-fold cross validation for all of the models
bucket_endpoints = np.linspace(0, df.shape[0], k + 1).round()
for model_name, model in models.items():
    features = model['features']
    target = model['target']
    for idx in range(len(bucket_endpoints)-1):
        # specify in-sample and out-of-sample subsets
        out_of_sample_mask = (df.index >= bucket_endpoints[idx]) & (df.index < bucket_endpoints[idx+1])
        in_sample_data = df.loc[~out_of_sample_mask].copy(deep=True)
        
        # train the model
        A_in_sample = np.vstack([in_sample_data[features].values.T, np.ones(in_sample_data.shape[0])]).T
        res = np.linalg.lstsq(A_in_sample, in_sample_data[target])
        
        # test the model on out of sample data (the performance metric we will use here is mean squared error)
        out_of_sample_data = df.loc[out_of_sample_mask].copy(deep=True)
        A_out_of_sample = np.vstack([out_of_sample_data[features].values.T, np.ones(out_of_sample_data.shape[0])]).T
        out_of_sample_data['prediction'] = np.dot(res[0].T, A_out_of_sample.T)[0]
        print 
        
        # compute mean squared eror
        mse = ((out_of_sample_data['prediction'] - out_of_sample_data[target])**2).mean()
        line_to_append = {
            'model_name': model_name,
            'features': features,
            'target': target,
            'mse': mse
        }
        results_df = results_df.append(line_to_append, ignore_index=True)

# %%
results_df
# Out:
#                                 features model_name       mse      target
# 0                           [log_length]    model_1  1.216388  log_volume
# 1                           [log_length]    model_1  1.727250  log_volume
# 2                           [log_length]    model_1  1.901433  log_volume
# 3                           [log_length]    model_1  0.770773  log_volume
# 4                           [log_length]    model_1  1.294196  log_volume
# 5                           [log_length]    model_1  3.821907  log_volume
# 6                           [log_length]    model_1  2.336363  log_volume
# 7                           [log_length]    model_1  1.956853  log_volume
# 8                           [log_length]    model_1  0.974054  log_volume
# 9                           [log_length]    model_1  3.687536  log_volume
# 10  [log_length, log_width, log_breadth]    model_2  1.216389  log_volume
# 11  [log_length, log_width, log_breadth]    model_2  1.727250  log_volume
# 12  [log_length, log_width, log_breadth]    model_2  1.901433  log_volume
# 13  [log_length, log_width, log_breadth]    model_2  0.770773  log_volume
# 14  [log_length, log_width, log_breadth]    model_2  1.294196  log_volume
# 15  [log_length, log_width, log_breadth]    model_2  3.821906  log_volume
# 16  [log_length, log_width, log_breadth]    model_2  2.336362  log_volume
# 17  [log_length, log_width, log_breadth]    model_2  1.956853  log_volume
# 18  [log_length, log_width, log_breadth]    model_2  0.974053  log_volume
# 19  [log_length, log_width, log_breadth]    model_2  3.687535  log_volume
