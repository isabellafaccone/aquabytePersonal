# %% [markdown]
# <h1> Biomass Regression Model </h1>

# %%
import array
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
import json
import math
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data_dir_base = '/root/blender'
COMPLETE_SAMPLE_SIZE = 4007
df = pd.DataFrame()
for idx in range(COMPLETE_SAMPLE_SIZE):
    # get annotation data
    annotation_file_name = 'annot_{}.json'.format(idx)
    annotation_file_path = '{}/{}/{}'.format(data_dir_base, 'annotations', annotation_file_name)
    annotation_data = json.load(open(annotation_file_path, 'rb'))
    df = df.append(annotation_data, ignore_index=True)

# %% [markdown]
# We first consider the model $ W = aL^b $, where $W$ and $L$ represent biomass and weight, respectively. First, rewrite the model as $\log{W} = a + b\log{L}$. We will fit the points to this model.

# %%
df['log_volume'] = np.log(df.volume)
df['log_length'] = np.log(df.length)
A = np.vstack([df.log_length, np.ones(df.shape[0])]).T
res = np.linalg.lstsq(A, df.log_volume)
m, b = res[0]

# %%
m, b
# Out:
# (-0.035269757062088687, 7.9668882932900358)

# %%
df
# Out:
#          height      length        unit unit_system       volume      width  \
# 0     20.978161  104.890807  centimeter      METRIC  2941.222084  17.481801
# 1     10.372520   51.862598  centimeter      METRIC  4550.174440   8.643766
# 2     17.134594   85.672969  centimeter      METRIC   551.489199  14.278828
# 3     25.848414  129.242071  centimeter      METRIC  2480.938307  21.540345
# 4     18.488120   92.440600  centimeter      METRIC  8507.703208  15.406767
# 5      9.413312   47.066562  centimeter      METRIC  3115.708490   7.844427
# 6     13.724868   68.624339  centimeter      METRIC   412.449349  11.437390
# 7     17.291973   86.459866  centimeter      METRIC  1276.018557  14.409978
# 8     24.756010  123.780052  centimeter      METRIC  2549.793119  20.630009
# 9     17.708573   88.542867  centimeter      METRIC  7474.747038  14.757144
# 10    25.832241  129.161206  centimeter      METRIC  2738.301161  21.526868
# 11    10.944467   54.722337  centimeter      METRIC  8491.689108   9.120389
# 12    22.906683  114.533415  centimeter      METRIC   647.695213  19.088903
# 13    12.794676   63.973380  centimeter      METRIC  5922.592905  10.662230
# 14    21.485409  107.427046  centimeter      METRIC  1034.102605  17.904508
# 15    21.614231  108.071155  centimeter      METRIC  4887.958268  18.011859
# 16    10.703990   53.519952  centimeter      METRIC  4976.279958   8.919992
# 17    11.436443   57.182214  centimeter      METRIC   606.004623   9.530369
# 18    23.714887  118.574434  centimeter      METRIC   738.848004  19.762406
# 19    12.306175   61.530875  centimeter      METRIC  6571.475800  10.255146
# 20    24.159109  120.795543  centimeter      METRIC   920.231979  20.132591
# 21    22.811577  114.057883  centimeter      METRIC  6947.182012  19.009647
# 22    16.595125   82.975625  centimeter      METRIC  5849.092745  13.829271
# 23    12.731710   63.658549  centimeter      METRIC  2254.088503  10.609758
# 24    16.663362   83.316810  centimeter      METRIC  1018.903301  13.886135
# 25    13.593264   67.966321  centimeter      METRIC  2282.009942  11.327720
# 26    15.810221   79.051103  centimeter      METRIC  1239.697035  13.175184
# 27     9.630816   48.154080  centimeter      METRIC  1949.437705   8.025680
# 28    23.186927  115.934637  centimeter      METRIC   441.638042  19.322439
# 29    20.108771  100.543855  centimeter      METRIC  6142.450130  16.757309
# ...         ...         ...         ...         ...          ...        ...
# 3977  24.295525  121.477625  centimeter      METRIC  7350.844712  20.246271
# 3978  10.747262   53.736310  centimeter      METRIC  7065.516788   8.956052
# 3979  18.971351   94.856754  centimeter      METRIC   613.344637  15.809459
# 3980  17.485196   87.425978  centimeter      METRIC  3366.131695  14.570996
# 3981  21.954454  109.772271  centimeter      METRIC  2636.109947  18.295379
# 3982  19.465682   97.328411  centimeter      METRIC  5214.817280  16.221402
# 3983  19.549622   97.748112  centimeter      METRIC  3636.059685  16.291352
# 3984  20.605619  103.028095  centimeter      METRIC  3683.197425  17.171349
# 3985  14.735156   73.675781  centimeter      METRIC  4312.268927  12.279297
# 3986  23.475593  117.377963  centimeter      METRIC  1578.610968  19.562994
# 3987  14.732730   73.663652  centimeter      METRIC  6374.554919  12.277275
# 3988  12.752879   63.764396  centimeter      METRIC  1577.828835  10.627399
# 3989  13.575938   67.879689  centimeter      METRIC  1023.975418  11.313281
# 3990  22.227630  111.138150  centimeter      METRIC  1234.998639  18.523025
# 3991  25.614402  128.072009  centimeter      METRIC  5411.807779  21.345335
# 3992  16.634435   83.172175  centimeter      METRIC  8278.802288  13.862029
# 3993  19.826014   99.130072  centimeter      METRIC  2270.102364  16.521679
# 3994  12.188527   60.942636  centimeter      METRIC  3841.454201  10.157106
# 3995  12.298886   61.494432  centimeter      METRIC   894.095938  10.249072
# 3996  20.356092  101.780459  centimeter      METRIC   918.624383  16.963410
# 3997  25.079370  125.396849  centimeter      METRIC  4157.643027  20.899475
# 3998  11.665507   58.327533  centimeter      METRIC  7770.996441   9.721256
# 3999  19.840866   99.204330  centimeter      METRIC   784.059440  16.534055
# 4000  10.395134   51.975671  centimeter      METRIC  3850.175791   8.662612
# 4001  24.081661  120.408303  centimeter      METRIC   555.111433  20.068050
# 4002  22.831030  114.155148  centimeter      METRIC  6880.733321  19.025858
# 4003  16.325277   81.626385  centimeter      METRIC  5864.183688  13.604398
# 4004  20.426557  102.132784  centimeter      METRIC  2145.976401  17.022131
# 4005  11.568339   57.841696  centimeter      METRIC  4200.739095   9.640283
# 4006  20.785180  103.925898  centimeter      METRIC   764.662717  17.320983
#
#       log_volume  log_length
# 0       7.986580    4.652920
# 1       8.422921    3.948598
# 2       6.312622    4.450537
# 3       7.816392    4.861687
# 4       9.048727    4.526566
# 5       8.044212    3.851563
# 6       6.022113    4.228647
# 7       7.151500    4.459680
# 8       7.843768    4.818506
# 9       8.919286    4.483487
# 10      7.915093    4.861061
# 11      9.046843    4.002272
# 12      6.473420    4.740867
# 13      8.686530    4.158467
# 14      6.941289    4.676812
# 15      8.494530    4.682790
# 16      8.512438    3.980055
# 17      6.406888    4.046243
# 18      6.605092    4.775541
# 19      8.790494    4.119539
# 20      6.824626    4.794099
# 21      8.846091    4.736706
# 22      8.674042    4.418547
# 23      7.720501    4.153534
# 24      6.926482    4.422650
# 25      7.732812    4.219012
# 26      7.122622    4.370095
# 27      7.575296    3.874406
# 28      6.090491    4.753027
# 29      8.722979    4.610594
# ...          ...         ...
# 3977    8.902571    4.799730
# 3978    8.862981    3.984089
# 3979    6.418927    4.552368
# 3980    8.121519    4.470792
# 3981    7.877060    4.698408
# 3982    8.559259    4.578091
# 3983    8.198656    4.582394
# 3984    8.211537    4.635002
# 3985    8.369219    4.299674
# 3986    7.364301    4.765399
# 3987    8.760070    4.299509
# 3988    7.363805    4.155195
# 3989    6.931448    4.217737
# 3990    7.118825    4.710774
# 3991    8.596338    4.852593
# 3992    9.021454    4.420913
# 3993    7.727580    4.596433
# 3994    8.253606    4.109933
# 3995    6.795813    4.118947
# 3996    6.822877    4.622818
# 3997    8.332704    4.831484
# 3998    8.958154    4.066074
# 3999    6.664485    4.597182
# 4000    8.255874    3.950776
# 4001    6.319169    4.790888
# 4002    8.836481    4.737558
# 4003    8.676619    4.402153
# 4004    7.671350    4.626274
# 4005    8.343016    4.057710
# 4006    6.639435    4.643678
#
# [4007 rows x 8 columns]
