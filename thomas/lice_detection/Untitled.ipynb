# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/root/data/lice/lice_erko/1533098426611_544_2272_crop_4.png',0)

# Initiate STAR detector
orb = cv2.ORB_create()

# find the keypoints with ORB
kp = orb.detect(img,None)

# compute the descriptors with ORB
kp, des = orb.compute(img, kp)

# draw only keypoints location,not size and orientation
img2 = cv2.drawKeypoints(img,kp, None, color=(0,255,0), flags=0)
plt.imshow(img2),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f22ef7284a8>, None)

# %%
kp
# Out:
# [<KeyPoint 0x7f22ef83bc30>,
#  <KeyPoint 0x7f22ef83bc60>,
#  <KeyPoint 0x7f22ef83bc90>,
#  <KeyPoint 0x7f22ef83bcc0>,
#  <KeyPoint 0x7f22ef83bcf0>,
#  <KeyPoint 0x7f22ef83bd20>,
#  <KeyPoint 0x7f22ef83bd50>,
#  <KeyPoint 0x7f22ef83bd80>,
#  <KeyPoint 0x7f22ef83bdb0>,
#  <KeyPoint 0x7f22ef83bde0>,
#  <KeyPoint 0x7f22ef83be10>,
#  <KeyPoint 0x7f22ef83be40>,
#  <KeyPoint 0x7f22ef83be70>,
#  <KeyPoint 0x7f22ef83bea0>,
#  <KeyPoint 0x7f22ef83bed0>,
#  <KeyPoint 0x7f22ef83bf00>,
#  <KeyPoint 0x7f22ef83bf30>,
#  <KeyPoint 0x7f22ef83bf60>,
#  <KeyPoint 0x7f22ef83bf90>,
#  <KeyPoint 0x7f22ef83bfc0>,
#  <KeyPoint 0x7f22ef83bc00>,
#  <KeyPoint 0x7f22ef848030>,
#  <KeyPoint 0x7f22ef848060>,
#  <KeyPoint 0x7f22ef848090>,
#  <KeyPoint 0x7f22ef8480c0>,
#  <KeyPoint 0x7f22ef8480f0>,
#  <KeyPoint 0x7f22ef848120>,
#  <KeyPoint 0x7f22ef848150>,
#  <KeyPoint 0x7f22ef848180>,
#  <KeyPoint 0x7f22ef8481b0>,
#  <KeyPoint 0x7f22ef8481e0>,
#  <KeyPoint 0x7f22ef848210>,
#  <KeyPoint 0x7f22ef848240>,
#  <KeyPoint 0x7f22ef848270>,
#  <KeyPoint 0x7f22ef8482a0>,
#  <KeyPoint 0x7f22ef8482d0>,
#  <KeyPoint 0x7f22ef848300>]
