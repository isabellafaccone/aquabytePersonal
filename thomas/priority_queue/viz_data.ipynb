# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# good images viz

# %%
good_images = glob.glob("/root/data/priority_queue/frames-resized/good/*.jpg")

# %%
good_images[0]
# Out:
# '/root/data/priority_queue/frames-resized/good/left_blom-kjeppevikholmen_2_1549548845685.jpg'

# %%
random_images = np.random.choice(good_images, 10)
for rim in random_images:
    image = cv2.imread(rim)
    plt.figure(figsize=(20, 10))
    plt.imshow(image)
    plt.axis("off")
    plt.show()

# %% [markdown]
# skipped images viz

# %%
images = glob.glob("/root/data/priority_queue/frames-resized/*/*.jpg")

# %%
image_classes = {}
for im in images:
    imtype = im.split("/")[-2]
    if imtype not in image_classes:
        image_classes[imtype] = []
    image_classes[imtype].append(im)

# %% [markdown]
# select the imtype to look at

# %%
imtype = "blurry"

# %%
random_images = np.random.choice(image_classes[imtype], 10)
for rim in random_images:
    image = cv2.imread(rim)
    plt.figure(figsize=(20, 10))
    plt.imshow(image)
    plt.axis("off")
    plt.show()
